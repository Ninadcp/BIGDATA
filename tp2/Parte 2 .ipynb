# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

#Seteamos el directorio en elq ue vamos a trabajar
directorio = '/Users/juanimorozumi/Documents/GitHub/BIGDATA/tp2'

#Le ponemos un nombre al archivo
archivo_nuevo = 'datos_sin_duplicados_sin_columnas.csv'

#Construimos la ruta entre el archivo y el directorio
ruta = os.path.join(directorio,archivo_nuevo)

#Cargamos el archivo en un data frame 
df = pd.read_csv(ruta)

#Mostramos las primeras filas del data frame 
print(df.head())
# Out:
#   neighbourhood_group  latitude  longitude        room_type  price  \
# 0            Brooklyn  40.64749  -73.97237     Private room  149.0
# 1           Manhattan  40.75362  -73.98377  Entire home/apt  225.0
# 2           Manhattan  40.80902  -73.94190     Private room  150.0
# 3            Brooklyn  40.68514  -73.95976  Entire home/apt   89.0
# 4           Manhattan  40.79851  -73.94399  Entire home/apt   80.0
#
#    minimum_nights  number_of_reviews  reviews_per_month  \
# 0               1                  9               0.21
# 1               1                 45               0.38
# 2               3                  0                NaN
# 3               1                270               4.64
# 4              10                  9               0.10
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355
# 2                               1               365
# ...

# %%
#Punto 1.
#Seleccionamos las variables para la matriz de correlación
variables = ['neighbourhood_group', 'latitude', 'longitude', 'room_type', 'price', 
             'minimum_nights', 'number_of_reviews', 'reviews_per_month', 
             'calculated_host_listings_count', 'availability_365']

# %%
# Crear una subconjunto de datos con las variables seleccionadas
subconjunto_datos = df[variables]

# %%
# Calcular la matriz de correlación
matriz_correlacion = subconjunto_datos.corr()
# Out:
# /var/folders/pv/088xlq6n437b0m1bfcy9zv840000gn/T/ipykernel_43812/2889081713.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   matriz_correlacion = subconjunto_datos.corr()

# %%
# Visualizar la matriz de correlación usando seaborn
plt.figure(figsize=(12, 8))
sns.heatmap(matriz_correlacion, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Matriz de correlación')
plt.show()

# %%
#Podemos notar que los cuadros entre los que se muestra una mayor correlación son los de: number_of_reviews y reviews_per_month. Luego entre las demas variables no podemos notar una alta correlación entre sí

# %%
#Punto 2.
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

#Seteamos el directorio en elq ue vamos a trabajar
directorio = '/Users/juanimorozumi/Documents/GitHub/BIGDATA/tp2'

#Le ponemos un nombre al archivo
archivo_nuevo = 'datos_sin_duplicados_sin_columnas.csv'

#Construimos la ruta entre el archivo y el directorio
ruta = os.path.join(directorio,archivo_nuevo)
#Cargamos el archivo en un data frame 
df = pd.read_csv(ruta)

#Mostramos las primeras filas del data frame 
print(df.head())
# Out:
#   neighbourhood_group  latitude  longitude        room_type  price  \
# 0            Brooklyn  40.64749  -73.97237     Private room  149.0
# 1           Manhattan  40.75362  -73.98377  Entire home/apt  225.0
# 2           Manhattan  40.80902  -73.94190     Private room  150.0
# 3            Brooklyn  40.68514  -73.95976  Entire home/apt   89.0
# 4           Manhattan  40.79851  -73.94399  Entire home/apt   80.0
#
#    minimum_nights  number_of_reviews  reviews_per_month  \
# 0               1                  9               0.21
# 1               1                 45               0.38
# 2               3                  0                NaN
# 3               1                270               4.64
# 4              10                  9               0.10
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355
# 2                               1               365
# ...

# %%
# Calcular la proporción de oferentes por "Neighbourhood group"
proporcion_por_barrio = df['neighbourhood_group'].value_counts(normalize=True)

# Calcular la proporción de oferentes por tipo de habitación
proporcion_por_tipo_habitacion = df['room_type'].value_counts(normalize=True)

# %%
# Crear gráficos para mostrar las composiciones
plt.figure(figsize=(12, 6))

# %%
# Gráfico para la proporción por "Neighbourhood group"
plt.subplot(1, 2, 1)
proporcion_por_barrio.plot(kind='bar', color='skyblue')
plt.title('Proporción de oferentes por Neighbourhood group')
plt.xlabel('Neighbourhood group')
plt.ylabel('Proporción')
# Out:
# Text(0, 0.5, 'Proporción')

# %%
#Podemos ver como las zonas de Manhattan y Brooklyn son las zonas por las que tienen una mayor proporción de la busqueda por el grupo de vecinos.

# %%
# Gráfico para la proporción por tipo de habitación
plt.subplot(1, 2, 2)
proporcion_por_tipo_habitacion.plot(kind='bar', color='salmon')
plt.title('Proporción de oferentes por tipo de habitación')
plt.xlabel('Tipo de habitación')
plt.ylabel('Proporción')

plt.tight_layout()
plt.show()

# %%
#Los más buscado en Airbnb son las casas o los departamentos completos, que se llevan más de la mitad de la proporción de las busquedas.
#Mientras que las habitaciones privadas son las segundas más buscadas, superando más del 40%.

# %%
#Punto 3
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

#Seteamos el directorio en elq ue vamos a trabajar
directorio = '/Users/juanimorozumi/Documents/GitHub/BIGDATA/tp2'

#Le ponemos un nombre al archivo
archivo_nuevo = 'datos_sin_duplicados_sin_columnas.csv'

#Construimos la ruta entre el archivo y el directorio
ruta = os.path.join(directorio,archivo_nuevo)
#Cargamos el archivo en un data frame 
df = pd.read_csv(ruta)

#Mostramos las primeras filas del data frame 
print(df.head())
# Out:
#   neighbourhood_group  latitude  longitude        room_type  price  \
# 0            Brooklyn  40.64749  -73.97237     Private room  149.0
# 1           Manhattan  40.75362  -73.98377  Entire home/apt  225.0
# 2           Manhattan  40.80902  -73.94190     Private room  150.0
# 3            Brooklyn  40.68514  -73.95976  Entire home/apt   89.0
# 4           Manhattan  40.79851  -73.94399  Entire home/apt   80.0
#
#    minimum_nights  number_of_reviews  reviews_per_month  \
# 0               1                  9               0.21
# 1               1                 45               0.38
# 2               3                  0                NaN
# 3               1                270               4.64
# 4              10                  9               0.10
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355
# 2                               1               365
# ...

# %%
# Histograma de precios de los alojamientos
plt.figure(figsize=(10, 6))
plt.hist(df['price'], bins=30, color='skyblue', edgecolor='black')
plt.title('Histograma de precios de alojamientos')
plt.xlabel('Precio')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()

# Obtener el precio mínimo, máximo y promedio
precio_minimo = df['price'].min()
precio_maximo = df['price'].max()
precio_promedio = df['price'].mean()

print(f'Precio mínimo: {precio_minimo}')
print(f'Precio máximo: {precio_maximo}')
print(f'Precio promedio: {precio_promedio}')

# Calcular la media de precio por "Neighbourhood group" y por tipo de habitación
media_precio_por_barrio = df.groupby('neighbourhood_group')['price'].mean()
media_precio_por_tipo_habitacion = df.groupby('room_type')['price'].mean()

print('\nMedia de precio por Neighbourhood_group:')
print(media_precio_por_barrio)

print('\nMedia de precio por tipo de habitación:')
print(media_precio_por_tipo_habitacion)
# Out:
# Precio mínimo: 0.0
# Precio máximo: 10000.0
# Precio promedio: 152.73213993453356
#
# Media de precio por Neighbourhood_group:
# neighbourhood_group
# Bronx             87.464646
# Brooklyn         124.391451
# Manhattan        196.878654
# Queens            99.536900
# Staten Island    114.812332
# Name: price, dtype: float64
#
# Media de precio por tipo de habitación:
# room_type
# Entire home/apt    211.799677
# Private room        89.784908
# Shared room         70.127586
# Name: price, dtype: float64

# %%
# Podemos notar que el histograma alcanza un precio máximo de 10000 y un mínimo de 0, además de obtener un valor medio de 152,7 aproximadamente.
# Además, podemos observar la media de los precios de las zonas analizadas por Airbnb. Donde el menor precio lo podemos encontrar en Bronx y en Manhattan, el mayor.

# %%
#Punto 4 
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

#Seteamos el directorio en elq ue vamos a trabajar
directorio = '/Users/juanimorozumi/Documents/GitHub/BIGDATA/tp2'

#Le ponemos un nombre al archivo
archivo_nuevo = 'datos_sin_duplicados_sin_columnas.csv'

#Construimos la ruta entre el archivo y el directorio
ruta = os.path.join(directorio,archivo_nuevo)
#Cargamos el archivo en un data frame 
df = pd.read_csv(ruta)

#Mostramos las primeras filas del data frame 
print(df.head())
# Out:
#   neighbourhood_group  latitude  longitude        room_type  price  \
# 0            Brooklyn  40.64749  -73.97237     Private room  149.0
# 1           Manhattan  40.75362  -73.98377  Entire home/apt  225.0
# 2           Manhattan  40.80902  -73.94190     Private room  150.0
# 3            Brooklyn  40.68514  -73.95976  Entire home/apt   89.0
# 4           Manhattan  40.79851  -73.94399  Entire home/apt   80.0
#
#    minimum_nights  number_of_reviews  reviews_per_month  \
# 0               1                  9               0.21
# 1               1                 45               0.38
# 2               3                  0                NaN
# 3               1                270               4.64
# 4              10                  9               0.10
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355
# 2                               1               365
# ...

# %%
# Scatter plot 1: Price vs. Number_of_Reviews
plt.figure(figsize=(10, 6))
plt.scatter(df['number_of_reviews'], df['price'], alpha=0.5, color='skyblue')
plt.title('Precio vs. Número de reseñas')
plt.xlabel('Número de reseñas')
plt.ylabel('Precio')
plt.grid(True)
plt.show()

# Scatter plot 2: Tipo de habitaciónvs. Reviews per Month
plt.figure(figsize=(10, 6))
plt.scatter(df['reviews_per_month'], df['room_type'], alpha=0.5, color='salmon')
plt.title('Tipo de habitación vs. Reseñas por mes')
plt.xlabel('Reseñas por mes')
plt.ylabel('Tipo de hbaitación')
plt.grid(True)
plt.show()

# %%
#Punto 5
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
#Seteamos el directorio en elq ue vamos a trabajar
directorio = '/Users/juanimorozumi/Documents/GitHub/BIGDATA/tp2'

#Le ponemos un nombre al archivo
archivo_nuevo = 'datos_sin_duplicados_sin_columnas.csv'

#Construimos la ruta entre el archivo y el directorio
ruta = os.path.join(directorio,archivo_nuevo)
#Cargamos el archivo en un data frame 
df = pd.read_csv(ruta)

#Mostramos las primeras filas del data frame 
print(df.head())

#Eliminamos las variables no numéricas que se encuentran en la base de datos.
df = df.dropna()
#Esto se hace para poder usar el metodo componentes principales
# Out:
#   neighbourhood_group  latitude  longitude        room_type  price  \
# 0            Brooklyn  40.64749  -73.97237     Private room  149.0
# 1           Manhattan  40.75362  -73.98377  Entire home/apt  225.0
# 2           Manhattan  40.80902  -73.94190     Private room  150.0
# 3            Brooklyn  40.68514  -73.95976  Entire home/apt   89.0
# 4           Manhattan  40.79851  -73.94399  Entire home/apt   80.0
#
#    minimum_nights  number_of_reviews  reviews_per_month  \
# 0               1                  9               0.21
# 1               1                 45               0.38
# 2               3                  0                NaN
# 3               1                270               4.64
# 4              10                  9               0.10
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355
# 2                               1               365
# ...

# %%
# Seleccionar las variables para el PCA
variables_pca = ['latitude', 'longitude', 'price', 'minimum_nights', 
                 'number_of_reviews', 'reviews_per_month', 
                 'calculated_host_listings_count', 'availability_365']

# %%
# Preprocesamiento: estandarizar las variables
scaler = StandardScaler()
datos_estandarizados = scaler.fit_transform(df[variables_pca])

# %%
# Realizar PCA
pca = PCA(n_components=2)
componentes_principales = pca.fit_transform(datos_estandarizados)

# Porcentaje de varianza explicada por las dos componentes principales
varianza_explicada = pca.explained_variance_ratio_
print("Porcentaje de varianza explicada por dos componentes:", sum(varianza_explicada)*100)

# Crear un DataFrame para los loadings
loadings = pd.DataFrame(pca.components_.T, columns=['PC1', 'PC2'], index=variables_pca)

# Graficar las variables en dos dimensiones usando las dos primeras componentes principales
plt.figure(figsize=(10, 6))
plt.scatter(componentes_principales[:, 0], componentes_principales[:, 1], alpha=0.5)
plt.title('Variables en dos dimensiones (PCA)')
plt.xlabel('Componente Principal 1')
plt.ylabel('Componente Principal 2')

# Anotar los loadings en el gráfico
for variable, (pc1, pc2) in loadings.iterrows():
    plt.annotate(variable,(pc1, pc2), color='red')

plt.grid(True)
plt.show()
# Out:
# Porcentaje de varianza explicada por dos componentes: 37.69935581758133
