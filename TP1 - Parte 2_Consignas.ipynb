# %% [markdown]
# # Curso de Big Data. Otoño 2024
# ### MOROZUMI _ DE LEÓN _ DI COSTANZO PEREIRA
#
#
# ## Trabajo Práctico 1 - Parte 2

# %% [markdown]
# ### Reglas de formato y presentación
# - El trabajo debe estar bien comentado (utilizando #) para que el código sea fácil de entender por sus compañeros y profesores.
#
# - El mismo debe ser completado en este Jupyter Notebook y entregado como tal, es decir en un archivo .ipynb

# %% [markdown]
# ### Fecha de entrega:
# Domingo 24 de marzo a las 23:59hs

# %% [markdown]
# ### Modalidad de entrega
# - Al finalizar el trabajo práctico deben hacer un último <i>commit</i> en su repositorio de GitHub con el mensaje “Entrega final del tp”.
# - Asegurense de haber creado una carpeta llamada TP1. Este Jupyter Notebook y el correspondiente al TP1 - Parte 2 deben estar dentro de esa carpeta.
# - También deben enviar el link de su repositorio -para que pueda ser clonado y corregido- al siguiente email: v.oubina@gmail.com
# - La última versión en el repositorio es la que será evaluada. Por lo que es importante que:
#     - No envien el correo hasta no haber terminado y estar seguros de que han hecho el <i>commit y push</i> a la versión final que quieren entregar. Debido a que se pueden tomar hasta 3 días de extensión a lo largo del curso, no se corregirán sus tareas hasta no recibir el correo.
#     - No hagan nuevos <i>push</i> despues de haber entregado su versión final. Esto generaría confusión acerca de que versión es la que quieren que se les corrija.

# %% [markdown]
# ### Parte A

# %% [markdown]
# #### Ejercicio 1
# Usando la API de Mercado Libre, obtener los ítems de una consulta de búsqueda. Pueden buscar cualquier producto de su interés.

# %%
import requests

# %%
buscar = "whey protein"
url = "https://api.mercadolibre.com/sites/{}/search?q={}".format("MLA", buscar.replace(" ", "%20"))

response = requests.request("GET",url)
print (response)
response.text
##Aquí obtendremos la respuesta total de la página API de mercado libre sobre las whey protein
# Out:
# <Response [200]>
# '{"site_id":"MLA","country_default_time_zone":"GMT-03:00","query":"whey protein","paging":{"total":6428,"primary_results":1000,"offset":0,"limit":50},"results":[{"id":"MLA1118855020","title":"Suplemento En Polvo Ena Sport  True Made Proteínas Sabor Vanilla Ice Cream En Pote De 930g","condition":"new","thumbnail_id":"957539-MLA50144895276_052022","catalog_product_id":"MLA14287435","listing_type_id":"gold_special","permalink":"https://www.mercadolibre.com.ar/suplemento-en-polvo-ena-sport-true-made-whey-protein-proteinas-sabor-vanilla-ice-cream-en-pote-de-930g/p/MLA14287435","buying_mode":"buy_it_now","site_id":"MLA","category_id":"MLA3551","domain_id":"MLA-SUPPLEMENTS","thumbnail":"http://http2.mlstatic.com/D_957539-MLA50144895276_052022-I.jpg","currency_id":"ARS","order_backend":1,"price":27560,"original_price":null,"sale_price":null,"available_quantity":100,"official_store_id":null,"use_thumbnail_id":true,"accepts_mercadopago":true,"shipping":{"store_pick_up":false,"free_shipping":true,"logistic_type":"fulfillment","mode":"me2","tags":["fulfillment","MLA-CHG-threshold-nov-23","self_service_out","mandatory_free_shipping"],"benefits":null,"promise":null},"stop_time":"2042-03-14T22:02:11.000Z","seller":{"id":245720358,"nickname":"LA-NELY"},"attributes":[{"id":"BRAND","name":"Marca","value_id":"5377326","value_name":"ENA Sport","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":"5377326","name":"ENA Sport","struct":null,"source":1}],"source":1,"value_type":"string"},{"id":"GTIN","name":"Código universal de producto","value_id":null,"value_name":"7792981060021","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":null,"name":"7792981060021","struct":null,"source":385122562515662}],"source":1,"value_type":"string"},{"id":"ITEM_CONDITION","name":"Condición del ítem","value_id":"2230284","value_name":"Nuevo","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":"2230284","name":"Nuevo","struct":null,"source":1}],"source":1,"value_type":"list"},{"id":"LINE","name":"Línea","value_id":null,"value_name":"True Made","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":null,"name":"True Made","struct":null,"source":3376461333454861}],"source":3376461333454861,"value_type":"string"},{"id":"NET_VOLUME","name":"Volumen neto","value_id":"-1","value_name":null,"attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":"-1","name":null,"struct":null,"source":377188858949192}],"source":377188858949192,"value_type":"number_unit"},{"id":"NET_WEIGHT","name":"Peso neto","value_id":"11173041","value_name":"930 g","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":{"number":930,"unit":"g"},"values":[{"id":"11173041","name":"930 g","struct":{"number":930,"unit":"g"},"source":1}],"source":1,"value_type":"number_unit"},{"id":"SALE_FORMAT","name":"Formato de venta","value_id":"1359391","value_name":"Unidad","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":"1359391","name":"Unidad","struct":null,"source":1}],"source":1,"value_type":"list"},{"id":"SERVING_WEIGHT","name":"Peso de la porción","value_id":"11140143","value_name":"31 g","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":{"number":31,"unit":"g"},"values":[{"id":"11140143","name":"31 g","struct":{"number":31,"unit":"g"},"source":1}],"source":1,"value_type":"number_unit"},{"id":"UNITS_PER_PACK","name":"Unidades por pack","value_id":"2726554","value_name":"1","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":"2726554","name":"1","struct":null,"source":1}],"source":1,"value_type":"number"},{"id":"UNITS_PER_PACKAGE","name":"Unidades por envase","value_id":"2726554","value_name":"1","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_s ...

# %%
## Ahora organizaremos los datos para que sea mas fácil de ver
data = response.json()
data
# Out:
# {'site_id': 'MLA',
#  'country_default_time_zone': 'GMT-03:00',
#  'query': 'whey protein',
#  'paging': {'total': 6428, 'primary_results': 1000, 'offset': 0, 'limit': 50},
#  'results': [{'id': 'MLA1118855020',
#    'title': 'Suplemento En Polvo Ena Sport  True Made Proteínas Sabor Vanilla Ice Cream En Pote De 930g',
#    'condition': 'new',
#    'thumbnail_id': '957539-MLA50144895276_052022',
#    'catalog_product_id': 'MLA14287435',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://www.mercadolibre.com.ar/suplemento-en-polvo-ena-sport-true-made-whey-protein-proteinas-sabor-vanilla-ice-cream-en-pote-de-930g/p/MLA14287435',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA3551',
#    'domain_id': 'MLA-SUPPLEMENTS',
#    'thumbnail': 'http://http2.mlstatic.com/D_957539-MLA50144895276_052022-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 1,
#    'price': 27560,
#    'original_price': None,
#    'sale_price': None,
#    'available_quantity': 100,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'fulfillment',
#     'mode': 'me2',
#     'tags': ['fulfillment',
#      'MLA-CHG-threshold-nov-23',
#      'self_service_out',
#      'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2042-03-14T22:02:11.000Z',
#    'seller': {'id': 245720358, 'nickname': 'LA-NELY'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '5377326',
#      'value_name': 'ENA Sport',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '5377326',
#        'name': 'ENA Sport',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'GTIN',
#      'name': 'Código universal de producto',
#      'value_id': None,
#      'value_name': '7792981060021',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '7792981060021',
#        'struct': None,
#        'source': 385122562515662}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'LINE',
#      'name': 'Línea',
#      'value_id': None,
#      'value_name': 'True Made',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': 'True Made',
#        'struct': None,
#        'source': 3376461333454861}],
#      'source': 3376461333454861,
#      'value_type': 'string'},
#     {'id': 'NET_VOLUME',
#      'name': 'Volumen neto',
#      'value_id': '-1',
#      'value_name': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '-1',
#        'name': None,
#        'struct': None,
#        'source': 377188858949192}],
#      'source': 377188858949192,
#      'value_type': 'number_unit'},
#     {'id': 'NET_WEIGHT',
#      'name': 'Peso neto',
#      'value_id': '11173041',
#      'value_name': '930 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 930, 'unit': 'g'},
#      'values': [{'id': '11173041',
#        'name': '930 g',
#        'struct': {'number': 930, 'unit': 'g'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'SALE_FORMAT',
#      'name': 'Formato de venta',
#      'value_id': '1359391',
#      'value_name': 'Unidad',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '1359391',
#        'name': 'Unidad',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'SERVING_WEIGHT',
#      'name': 'Peso de la porción',
#      'value_id': '11140143',
#      'value_name': '31 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 31, 'unit': 'g'},
#      'values': [{'id': '11140143',
#        'name': '31 g',
#        'struct': {'unit': 'g', 'number': 31},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'UNITS_PER_PACK',
#      'name': 'Unidades por pack',
#      'value_id': '2726554',
#      'value_name': '1',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2726554', 'name': '1', 'struct': None, 'source': 1}],
#      'source': 1,
#      'value_type': 'number'},
#     {'id': 'UNITS_PER_PACKAGE',
#      'name': 'Unidades por envase',
#      'value_id': '2726554',
#      'value_name': '1',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2726554',
#        'name': '1',
#        'struct': None,
#        'source': 377188858949192}],
#      'source': 377188858949192,
#      'value_type': 'number'},
#     {'id': 'UNIT_VOLUME',
#      'name': 'Volumen de la unidad',
#      'value_id': '-1',
#      'value_name': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '-1',
#        'name': None,
#        'struct': None,
#        'source': 3376461333454861}],
#      'source': 3376461333454861,
#      'value_type': 'number_unit'},
#     {'id': 'UNIT_WEIGHT',
#      'name': 'Peso de la unidad',
#      'value_id': '8004763',
#      'value_name': '930 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 930, 'unit': 'g'},
#      'values': [{'id': '8004763',
#        'name': '930 g',
#        'struct': {'unit': 'g', 'number': 930},
#        'source': 4709228965570453}],
#      'source': 4709228965570453,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 6,
#     'amount': 7299.73,
#     'rate': 58.92,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': 'ARLR96480'},
#   {'id': 'MLA1135249007',
#    'title': 'Suplemento En Polvo Ena Sport  True Made Proteínas Sabor Double Rich Chocolate En Pote De 930g',
#    'condition': 'new',
#    'thumbnail_id': '786807-MLA50144914161_052022',
#    'catalog_product_id': 'MLA14287437',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://www.mercadolibre.com.ar/suplemento-en-polvo-ena-sport-true-made-proteinas-sabor-double-rich-chocolate-en-pote-de-930g/p/MLA14287437',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA3551',
#    'domain_id': 'MLA-SUPPLEMENTS',
#    'thumbnail': 'http://http2.mlstatic.com/D_786807-MLA50144914161_052022-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 2,
#    'price': 27200,
#    'original_price': None,
#    'sale_price': None,
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'xd_drop_off',
#     'mode': 'me2',
#     'tags': ['MLA-chg-threshold-Feb-23',
#      'self_service_in',
#      'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2042-04-28T04:00:00.000Z',
#    'seller': {'id': 93622393, 'nickname': 'PITBULL SUPLEMENTOS'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '5377326',
#      'value_name': 'ENA Sport',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '5377326',
#        'name': 'ENA Sport',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'GTIN',
#      'name': 'Código universal de producto',
#      'value_id': None,
#      'value_name': '7792981062018',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '7792981062018',
#        'struct': None,
#        'source': 8910742901282450}],
#      'source': 8910742901282450,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'LINE',
#      'name': 'Línea',
#      'value_id': '12971528',
#      'value_name': 'Whey Protein',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '12971528',
#        'name': 'Whey Protein',
#        'struct': None,
#        'source': 3376461333454861}],
#      'source': 3376461333454861,
#      'value_type': 'string'},
#     {'id': 'NET_WEIGHT',
#      'name': 'Peso neto',
#      'value_id': '11173041',
#      'value_name': '930 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 930, 'unit': 'g'},
#      'values': [{'id': '11173041',
#        'name': '930 g',
#        'struct': {'number': 930, 'unit': 'g'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_LENGTH',
#      'name': 'Largo del paquete',
#      'value_id': None,
#      'value_name': '15.6 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 15.6, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '15.6 cm',
#        'struct': {'number': 15.6, 'unit': 'cm'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_WEIGHT',
#      'name': 'Peso del paquete',
#      'value_id': None,
#      'value_name': '1120 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 1120, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '1120 g',
#        'struct': {'unit': 'g', 'number': 1120},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'SALE_FORMAT',
#      'name': 'Formato de venta',
#      'value_id': '1359391',
#      'value_name': 'Unidad',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '1359391',
#        'name': 'Unidad',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'SERVING_WEIGHT',
#      'name': 'Peso de la porción',
#      'value_id': '11140143',
#      'value_name': '31 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 31, 'unit': 'g'},
#      'values': [{'id': '11140143',
#        'name': '31 g',
#        'struct': {'number': 31, 'unit': 'g'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'UNITS_PER_PACK',
#      'name': 'Unidades por pack',
#      'value_id': '2726554',
#      'value_name': '1',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2726554', 'name': '1', 'struct': None, 'source': 1}],
#      'source': 1,
#      'value_type': 'number'},
#     {'id': 'UNITS_PER_PACKAGE',
#      'name': 'Unidades por envase',
#      'value_id': '2726554',
#      'value_name': '1',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2726554',
#        'name': '1',
#        'struct': None,
#        'source': 3376461333454861}],
#      'source': 3376461333454861,
#      'value_type': 'number'},
#     {'id': 'UNIT_VOLUME',
#      'name': 'Volumen de la unidad',
#      'value_id': None,
#      'value_name': '908 mL',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 908, 'unit': 'mL'},
#      'values': [{'id': None,
#        'name': '908 mL',
#        'struct': {'number': 908, 'unit': 'mL'},
#        'source': 3376461333454861}],
#      'source': 3376461333454861,
#      'value_type': 'number_unit'},
#     {'id': 'UNIT_WEIGHT',
#      'name': 'Peso de la unidad',
#      'value_id': '8004763',
#      'value_name': '930 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 930, 'unit': 'g'},
#      'values': [{'id': '8004763',
#        'name': '930 g',
#        'struct': {'number': 930, 'unit': 'g'},
#        'source': 4709228965570453}],
#      'source': 4709228965570453,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 6,
#     'amount': 7204.37,
#     'rate': 58.92,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': 'XTNR03793'},
#   {'id': 'MLA1419625930',
#    'title': 'Suplemento En Polvo Star Nutrition  Platinum Whey Protein Proteína Sabor Chocolate Suizo En Pote De 908g',
#    'condition': 'new',
#    'thumbnail_id': '656339-MLU75001245993_032024',
#    'catalog_product_id': 'MLA18710124',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://www.mercadolibre.com.ar/suplemento-en-polvo-star-nutrition-platinum-whey-protein-proteina-sabor-chocolate-suizo-en-pote-de-908g/p/MLA18710124',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA3551',
#    'domain_id': 'MLA-SUPPLEMENTS',
#    'thumbnail': 'http://http2.mlstatic.com/D_656339-MLU75001245993_032024-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 3,
#    'price': 27465,
#    'original_price': 37128,
#    'sale_price': None,
#    'available_quantity': 200,
#    'official_store_id': 65728,
#    'official_store_name': 'Ecomodico',
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'cross_docking',
#     'mode': 'me2',
#     'tags': ['self_service_in', 'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2043-05-13T04:00:00.000Z',
#    'seller': {'id': 179907718, 'nickname': 'ECOMODICO'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '438470',
#      'value_name': 'Star Nutrition',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '438470',
#        'name': 'Star Nutrition',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'GTIN',
#      'name': 'Código universal de producto',
#      'value_id': None,
#      'value_name': '619660878777',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '619660878777',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 2860837171021627}],
#      'source': 2860837171021627,
#      'value_type': 'list'},
#     {'id': 'LINE',
#      'name': 'Línea',
#      'value_id': '12737',
#      'value_name': 'Platinum',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '12737',
#        'name': 'Platinum',
#        'struct': None,
#        'source': 2860837171021627}],
#      'source': 2860837171021627,
#      'value_type': 'string'},
#     {'id': 'NET_WEIGHT',
#      'name': 'Peso neto',
#      'value_id': '135515',
#      'value_name': '907 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 907, 'unit': 'g'},
#      'values': [{'id': '135515',
#        'name': '907 g',
#        'struct': {'unit': 'g', 'number': 907},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_LENGTH',
#      'name': 'Largo del paquete',
#      'value_id': None,
#      'value_name': '15 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 15, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '15 cm',
#        'struct': {'number': 15, 'unit': 'cm'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_WEIGHT',
#      'name': 'Peso del paquete',
#      'value_id': None,
#      'value_name': '1100 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 1100, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '1100 g',
#        'struct': {'number': 1100, 'unit': 'g'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'SALE_FORMAT',
#      'name': 'Formato de venta',
#      'value_id': '1359391',
#      'value_name': 'Unidad',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '1359391',
#        'name': 'Unidad',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'SERVING_WEIGHT',
#      'name': 'Peso de la porción',
#      'value_id': '11020467',
#      'value_name': '30 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 30, 'unit': 'g'},
#      'values': [{'id': '11020467',
#        'name': '30 g',
#        'struct': {'number': 30, 'unit': 'g'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'UNITS_PER_PACK',
#      'name': 'Unidades por pack',
#      'value_id': '2726554',
#      'value_name': '1',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2726554', 'name': '1', 'struct': None, 'source': 1}],
#      'source': 1,
#      'value_type': 'number'},
#     {'id': 'UNIT_VOLUME',
#      'name': 'Volumen de la unidad',
#      'value_id': '-1',
#      'value_name': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '-1',
#        'name': None,
#        'struct': None,
#        'source': 3376461333454861}],
#      'source': 3376461333454861,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 6,
#     'amount': 7274.56,
#     'rate': 58.92,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': 'RSJU15936'},
#   {'id': 'MLA1202276623',
#    'title': 'Whey Protein 3kg Body Advance Proteína Concentrada Premium Sabor Vainilla',
#    'condition': 'new',
#    'thumbnail_id': '826238-MLA48894979327_012022',
#    'catalog_product_id': 'MLA18529580',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://www.mercadolibre.com.ar/whey-protein-3kg-body-advance-proteina-concentrada-premium-sabor-vainilla/p/MLA18529580',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA8830',
#    'domain_id': 'MLA-SUPPLEMENTS',
#    'thumbnail': 'http://http2.mlstatic.com/D_826238-MLA48894979327_012022-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 4,
#    'price': 36267,
#    'original_price': None,
#    'sale_price': None,
#    'available_quantity': 100,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'fulfillment',
#     'mode': 'me2',
#     'tags': ['fulfillment', 'self_service_out', 'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2043-04-12T19:02:03.000Z',
#    'seller': {'id': 1221081614, 'nickname': 'GOLDBODYSUPPLEMENTS'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '11206615',
#      'value_name': 'Body Advance',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '11206615',
#        'name': 'Body Advance',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'GTIN',
#      'name': 'Código universal de producto',
#      'value_id': None,
#      'value_name': '0656750746158',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '0656750746158',
#        'struct': None,
#        'source': 385122562515662}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 3045741222775799}],
#      'source': 3045741222775799,
#      'value_type': 'list'},
#     {'id': 'LINE',
#      'name': 'Línea',
#      'value_id': '11316654',
#      'value_name': 'Gold Line',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '11316654',
#        'name': 'Gold Line',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'NET_WEIGHT',
#      'name': 'Peso neto',
#      'value_id': '135532',
#      'value_name': '3 kg',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 3, 'unit': 'kg'},
#      'values': [{'id': '135532',
#        'name': '3 kg',
#        'struct': {'number': 3, 'unit': 'kg'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_LENGTH',
#      'name': 'Largo del paquete',
#      'value_id': None,
#      'value_name': '19.4 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 19.4, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '19.4 cm',
#        'struct': {'number': 19.4, 'unit': 'cm'},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_WEIGHT',
#      'name': 'Peso del paquete',
#      'value_id': None,
#      'value_name': '3280 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 3280, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '3280 g',
#        'struct': {'number': 3280, 'unit': 'g'},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'},
#     {'id': 'SALE_FORMAT',
#      'name': 'Formato de venta',
#      'value_id': '1359391',
#      'value_name': 'Unidad',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '1359391',
#        'name': 'Unidad',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'SERVING_WEIGHT',
#      'name': 'Peso de la porción',
#      'value_id': '11006993',
#      'value_name': '40 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 40, 'unit': 'g'},
#      'values': [{'id': '11006993',
#        'name': '40 g',
#        'struct': {'number': 40, 'unit': 'g'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'UNITS_PER_PACK',
#      'name': 'Unidades por pack',
#      'value_id': '2726554',
#      'value_name': '1',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2726554', 'name': '1', 'struct': None, 'source': 1}],
#      'source': 1,
#      'value_type': 'number'},
#     {'id': 'UNITS_PER_PACKAGE',
#      'name': 'Unidades por envase',
#      'value_id': '2726554',
#      'value_name': '1',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2726554', 'name': '1', 'struct': None, 'source': 1}],
#      'source': 1,
#      'value_type': 'number'}],
#    'installments': {'quantity': 6,
#     'amount': 9605.92,
#     'rate': 58.92,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': 'VWSZ25026'},
#   {'id': 'MLA1369297215',
#    'title': 'Suplemento En Polvo Ena Sport  True Made Whey Protein Proteínas Sabor Cookies & Cream En Pote De 930g',
#    'condition': 'new',
#    'thumbnail_id': '972789-MLA50144914108_052022',
#    'catalog_product_id': 'MLA14287436',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://www.mercadolibre.com.ar/suplemento-en-polvo-ena-sport-true-made-whey-protein-proteinas-sabor-cookies-cream-en-pote-de-930g/p/MLA14287436',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA3551',
#    'domain_id': 'MLA-SUPPLEMENTS',
#    'thumbnail': 'http://http2.mlstatic.com/D_972789-MLA50144914108_052022-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 5,
#    'price': 27200,
#    'original_price': None,
#    'sale_price': None,
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'xd_drop_off',
#     'mode': 'me2',
#     'tags': ['MLA-chg-threshold-Feb-23',
#      'self_service_in',
#      'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2043-05-06T04:00:00.000Z',
#    'seller': {'id': 93622393, 'nickname': 'PITBULL SUPLEMENTOS'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '5377326',
#      'value_name': 'ENA Sport',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '5377326',
#        'name': 'ENA Sport',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'GTIN',
#      'name': 'Código universal de producto',
#      'value_id': None,
#      'value_name': '7792981062025',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '7792981062025',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'LINE',
#      'name': 'Línea',
#      'value_id': '12971528',
#      'value_name': 'Whey Protein',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '12971528',
#        'name': 'Whey Protein',
#        'struct': None,
#        'source': 3376461333454861}],
#      'source': 3376461333454861,
#      'value_type': 'string'},
#     {'id': 'NET_WEIGHT',
#      'name': 'Peso neto',
#      'value_id': '11173041',
#      'value_name': '930 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 930, 'unit': 'g'},
#      'values': [{'id': '11173041',
#        'name': '930 g',
#        'struct': {'number': 930, 'unit': 'g'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_LENGTH',
#      'name': 'Largo del paquete',
#      'value_id': None,
#      'value_name': '15 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 15, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '15 cm',
#        'struct': {'number': 15, 'unit': 'cm'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_WEIGHT',
#      'name': 'Peso del paquete',
#      'value_id': None,
#      'value_name': '1120 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 1120, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '1120 g',
#        'struct': {'number': 1120, 'unit': 'g'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'SALE_FORMAT',
#      'name': 'Formato de venta',
#      'value_id': '1359391',
#      'value_name': 'Unidad',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '1359391',
#        'name': 'Unidad',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'SERVING_WEIGHT',
#      'name': 'Peso de la porción',
#      'value_id': '11140143',
#      'value_name': '31 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 31, 'unit': 'g'},
#      'values': [{'id': '11140143',
#        'name': '31 g',
#        'struct': {'number': 31, 'unit': 'g'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'UNITS_PER_PACK',
#      'name': 'Unidades por pack',
#      'value_id': '2726554',
#      'value_name': '1',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2726554', 'name': '1', 'struct': None, 'source': 1}],
#      'source': 1,
#      'value_type': 'number'},
#     {'id': 'UNITS_PER_PACKAGE',
#      'name': 'Unidades por envase',
#      'value_id': '2726554',
#      'value_name': '1',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2726554', 'name': '1', 'struct': None, 'source': 1}],
#      'source': 1,
#      'value_type': 'number'},
#     {'id': 'UNIT_VOLUME',
#      'name': 'Volumen de la unidad',
#      'value_id': None,
#      'value_name': '908 mL',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 908, 'unit': 'mL'},
#      'values': [{'id': None,
#        'name': '908 mL',
#        'struct': {'unit': 'mL', 'number': 908},
#        'source': 3376461333454861}],
#      'source': 3376461333454861,
#      'value_type': 'number_unit'},
#     {'id': 'UNIT_WEIGHT',
#      'name': 'Peso de la unidad',
#      'value_id': '8004763',
#      'value_name': '930 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 930, 'unit': 'g'},
#      'values': [{'id': '8004763',
#        'name': '930 g',
#        'struct': {'unit': 'g', 'number': 930},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 6,
#     'amount': 7204.37,
#     'rate': 58.92,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': 'XOQO99663'},
#   {'id': 'MLA1246672642',
#    'title': 'Whey Protein Body Advance 3kg Glutamina Bcaa Vit C Creatina Sabor Chocolate',
#    'condition': 'new',
#    'thumbnail_id': '608098-MLA48894958748_012022',
#    'catalog_product_id': 'MLA18529578',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://www.mercadolibre.com.ar/whey-protein-body-advance-3kg-glutamina-bcaa-vit-c-creatina-sabor-chocolate/p/MLA18529578',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA3551',
#    'domain_id': 'MLA-SUPPLEMENTS',
#    'thumbnail': 'http://http2.mlstatic.com/D_608098-MLA48894958748_012022-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 6,
#    'price': 36267,
#    'original_price': None,
#    'sale_price': None,
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'fulfillment',
#     'mode': 'me2',
#     'tags': ['fulfillment', 'self_service_in', 'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2043-04-12T19:02:03.000Z',
#    'seller': {'id': 1221081614, 'nickname': 'GOLDBODYSUPPLEMENTS'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '11206615',
#      'value_name': 'Body Advance',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '11206615',
#        'name': 'Body Advance',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'GTIN',
#      'name': 'Código universal de producto',
#      'value_id': None,
#      'value_name': '0656750746165',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '0656750746165',
#        'struct': None,
#        'source': 385122562515662}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 3045741222775799}],
#      'source': 3045741222775799,
#      'value_type': 'list'},
#     {'id': 'LINE',
#      'name': 'Línea',
#      'value_id': '11316654',
#      'value_name': 'Gold Line',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '11316654',
#        'name': 'Gold Line',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'NET_VOLUME',
#      'name': 'Volumen neto',
#      'value_id': None,
#      'value_name': '300 mL',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 300, 'unit': 'mL'},
#      'values': [{'id': None,
#        'name': '300 mL',
#        'struct': {'number': 300, 'unit': 'mL'},
#        'source': 3045741222775799}],
#      'source': 3045741222775799,
#      'value_type': 'number_unit'},
#     {'id': 'NET_WEIGHT',
#      'name': 'Peso neto',
#      'value_id': '135532',
#      'value_name': '3 kg',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 3, 'unit': 'kg'},
#      'values': [{'id': '135532',
#        'name': '3 kg',
#        'struct': {'unit': 'kg', 'number': 3},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_LENGTH',
#      'name': 'Largo del paquete',
#      'value_id': None,
#      'value_name': '19.4 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 19.4, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '19.4 cm',
#        'struct': {'number': 19.4, 'unit': 'cm'},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_WEIGHT',
#      'name': 'Peso del paquete',
#      'value_id': None,
#      'value_name': '3220 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 3220, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '3220 g',
#        'struct': {'number': 3220, 'unit': 'g'},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'},
#     {'id': 'SALE_FORMAT',
#      'name': 'Formato de venta',
#      'value_id': '1359391',
#      'value_name': 'Unidad',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '1359391',
#        'name': 'Unidad',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'SERVING_WEIGHT',
#      'name': 'Peso de la porción',
#      'value_id': '11006993',
#      'value_name': '40 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 40, 'unit': 'g'},
#      'values': [{'id': '11006993',
#        'name': '40 g',
#        'struct': {'number': 40, 'unit': 'g'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'UNITS_PER_PACK',
#      'name': 'Unidades por pack',
#      'value_id': '2726554',
#      'value_name': '1',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2726554', 'name': '1', 'struct': None, 'source': 1}],
#      'source': 1,
#      'value_type': 'number'},
#     {'id': 'UNITS_PER_PACKAGE',
#      'name': 'Unidades por envase',
#      'value_id': '2726554',
#      'value_name': '1',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2726554', 'name': '1', 'struct': None, 'source': 1}],
#      'source': 1,
#      'value_type': 'number'}],
#    'installments': {'quantity': 6,
#     'amount': 9605.92,
#     'rate': 58.92,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': 'HGZF21855'},
#   {'id': 'MLA1140064175',
#    'title': 'Suplemento En Polvo Ena Sport  Whey X-pro Proteína Y Creatina Sabor Vanilla Ice Cream En Pote De 907g',
#    'condition': 'new',
#    'thumbnail_id': '752159-MLA48893905925_012022',
#    'catalog_product_id': 'MLA18725805',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://www.mercadolibre.com.ar/suplemento-en-polvo-ena-sport-whey-x-pro-proteina-y-creatina-sabor-vanilla-ice-cream-en-pote-de-907g/p/MLA18725805',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA8830',
#    'domain_id': 'MLA-SUPPLEMENTS',
#    'thumbnail': 'http://http2.mlstatic.com/D_752159-MLA48893905925_012022-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 7,
#    'price': 41550.23,
#    'original_price': 41550.23,
#    'sale_price': None,
#    'available_quantity': 100,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'fulfillment',
#     'mode': 'me2',
#     'tags': ['fulfillment',
#      'MLA-chg-threshold-feb-22',
#      'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2042-05-27T04:00:00.000Z',
#    'seller': {'id': 216066558, 'nickname': 'NS DISTRIBUCIONES'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '5377326',
#      'value_name': 'ENA Sport',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '5377326',
#        'name': 'ENA Sport',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'GTIN',
#      'name': 'Código universal de producto',
#      'value_id': None,
#      'value_name': '7792981060052',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '7792981060052',
#        'struct': None,
#        'source': 385122562515662}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 2860837171021627}],
#      'source': 2860837171021627,
#      'value_type': 'list'},
#     {'id': 'LINE',
#      'name': 'Línea',
#      'value_id': None,
#      'value_name': 'ENA Sport',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': 'ENA Sport',
#        'struct': None,
#        'source': 2860837171021627}],
#      'source': 2860837171021627,
#      'value_type': 'string'},
#     {'id': 'NET_VOLUME',
#      'name': 'Volumen neto',
#      'value_id': '-1',
#      'value_name': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '-1',
#        'name': None,
#        'struct': None,
#        'source': 2860837171021627}],
#      'source': 2860837171021627,
#      'value_type': 'number_unit'},
#     {'id': 'NET_WEIGHT',
#      'name': 'Peso neto',
#      'value_id': '135515',
#      'value_name': '907 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 907, 'unit': 'g'},
#      'values': [{'id': '135515',
#        'name': '907 g',
#        'struct': {'unit': 'g', 'number': 907},
#        'source': 4709228965570453}],
#      'source': 4709228965570453,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_LENGTH',
#      'name': 'Largo del paquete',
#      'value_id': None,
#      'value_name': '15 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 15, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '15 cm',
#        'struct': {'number': 15, 'unit': 'cm'},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_WEIGHT',
#      'name': 'Peso del paquete',
#      'value_id': None,
#      'value_name': '1100 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 1100, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '1100 g',
#        'struct': {'unit': 'g', 'number': 1100},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'},
#     {'id': 'SALE_FORMAT',
#      'name': 'Formato de venta',
#      'value_id': '1359391',
#      'value_name': 'Unidad',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '1359391',
#        'name': 'Unidad',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'SERVING_WEIGHT',
#      'name': 'Peso de la porción',
#      'value_id': '11106617',
#      'value_name': '33 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 33, 'unit': 'g'},
#      'values': [{'id': '11106617',
#        'name': '33 g',
#        'struct': {'unit': 'g', 'number': 33},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'UNITS_PER_PACK',
#      'name': 'Unidades por pack',
#      'value_id': '2726554',
#      'value_name': '1',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2726554', 'name': '1', 'struct': None, 'source': 1}],
#      'source': 1,
#      'value_type': 'number'},
#     {'id': 'UNITS_PER_PACKAGE',
#      'name': 'Unidades por envase',
#      'value_id': None,
#      'value_name': '30',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '30',
#        'struct': None,
#        'source': 2860837171021627}],
#      'source': 2860837171021627,
#      'value_type': 'number'},
#     {'id': 'UNIT_VOLUME',
#      'name': 'Volumen de la unidad',
#      'value_id': '-1',
#      'value_name': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '-1',
#        'name': None,
#        'struct': None,
#        'source': 2860837171021627}],
#      'source': 2860837171021627,
#      'value_type': 'number_unit'},
#     {'id': 'UNIT_WEIGHT',
#      'name': 'Peso de la unidad',
#      'value_id': None,
#      'value_name': '907 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 907, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '907 g',
#        'struct': {'number': 907, 'unit': 'g'},
#        'source': 2860837171021627}],
#      'source': 2860837171021627,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 6,
#     'amount': 11005.27,
#     'rate': 58.92,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': 'UZTW33115'},
#   {'id': 'MLA1135468751',
#    'title': 'Suplemento En Polvo +growth  Creatina Monohidratada Micronizada En Sachet De 300g',
#    'condition': 'new',
#    'thumbnail_id': '828496-MLU74135770990_012024',
#    'catalog_product_id': 'MLA18907239',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://www.mercadolibre.com.ar/suplemento-en-polvo-growth-creatina-monohidratada-micronizada-en-sachet-de-300g/p/MLA18907239',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA8830',
#    'domain_id': 'MLA-SUPPLEMENTS',
#    'thumbnail': 'http://http2.mlstatic.com/D_828496-MLU74135770990_012024-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 8,
#    'price': 7100,
#    'original_price': None,
#    'sale_price': None,
#    'available_quantity': 500,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': False,
#     'logistic_type': 'cross_docking',
#     'mode': 'me2',
#     'tags': ['self_service_in'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2042-04-29T04:00:00.000Z',
#    'seller': {'id': 242149367, 'nickname': 'ELNOGALGONZALO'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '11625945',
#      'value_name': '+Growth',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '11625945',
#        'name': '+Growth',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 6808261514773724}],
#      'source': 6808261514773724,
#      'value_type': 'list'},
#     {'id': 'LINE',
#      'name': 'Línea',
#      'value_id': '3697175',
#      'value_name': 'Deportiva',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '3697175',
#        'name': 'Deportiva',
#        'struct': None,
#        'source': 6808261514773724}],
#      'source': 6808261514773724,
#      'value_type': 'string'},
#     {'id': 'NET_WEIGHT',
#      'name': 'Peso neto',
#      'value_id': '135510',
#      'value_name': '300 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 300, 'unit': 'g'},
#      'values': [{'id': '135510',
#        'name': '300 g',
#        'struct': {'number': 300, 'unit': 'g'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'SALE_FORMAT',
#      'name': 'Formato de venta',
#      'value_id': '1359391',
#      'value_name': 'Unidad',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '1359391',
#        'name': 'Unidad',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'SERVING_WEIGHT',
#      'name': 'Peso de la porción',
#      'value_id': '11029849',
#      'value_name': '5 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 5, 'unit': 'g'},
# ...
#     {'id': '25484227', 'name': 'Varios', 'results': 15},
#     {'id': '11179827', 'name': 'Vainilla cream', 'results': 15},
#     {'id': '2749075', 'name': 'Frambuesa', 'results': 14},
#     {'id': '24631230', 'name': 'Strawberry Cream', 'results': 14},
#     {'id': '11313838', 'name': 'Vainilla gourmet', 'results': 13},
#     {'id': '11272217', 'name': 'Strawberry american cream', 'results': 13},
#     {'id': '11176052', 'name': 'Café con leche', 'results': 13},
#     {'id': '7613717', 'name': 'Unflavored', 'results': 12},
#     {'id': '16597790', 'name': 'Frutilla', 'results': 12},
#     {'id': '11310570', 'name': 'Gourmet vainilla', 'results': 12},
#     {'id': '2517714', 'name': 'Coco', 'results': 11},
#     {'id': '17709322', 'name': 'Cápsulas', 'results': 11},
#     {'id': '11579372', 'name': 'Chocolate milkshake', 'results': 11},
#     {'id': '11145666', 'name': 'Best whey banana', 'results': 11},
#     {'id': '6948272', 'name': 'Dark chocolate', 'results': 10},
#     {'id': '11145668', 'name': 'Best whey chocolate', 'results': 10},
#     {'id': '11141718', 'name': 'Lemon pie', 'results': 10},
#     {'id': '5060374', 'name': 'Chocolate peanut butter', 'results': 9},
#     {'id': '5060298', 'name': 'Chocolate brownie', 'results': 9},
#     {'id': '2342369', 'name': 'Maracuyá', 'results': 9},
#     {'id': '11145665', 'name': 'Best whey frutilla', 'results': 9},
#     {'id': '9777982', 'name': 'Chocolate/Vainilla', 'results': 8},
#     {'id': '5006283', 'name': 'Frutos del bosque', 'results': 8},
#     {'id': '22618913', 'name': 'Chocolate + Chocolate', 'results': 8},
#     {'id': '13251037', 'name': 'Surtido', 'results': 8},
#     {'id': '12096760', 'name': 'Capuchino', 'results': 8},
#     {'id': '9794271', 'name': 'Banana/Chocolate', 'results': 7},
#     {'id': '9777969', 'name': 'Vainilla/Chocolate', 'results': 7},
#     {'id': '15661559', 'name': 'Rich coffee', 'results': 7},
#     {'id': '13127977', 'name': 'Vainilla Caramel', 'results': 7},
#     {'id': '11635251', 'name': 'Chocolate fudge', 'results': 7},
#     {'id': '11145664', 'name': 'Best whey vainilla', 'results': 7},
#     {'id': '11138232', 'name': 'Chocolate/Frutilla', 'results': 7},
#     {'id': '5644065', 'name': 'Extreme milk chocolate', 'results': 6},
#     {'id': '5133179', 'name': 'Rich chocolate', 'results': 6},
#     {'id': '2656157', 'name': 'Jamón y queso', 'results': 5},
#     {'id': '2342368', 'name': 'Mango', 'results': 5},
#     {'id': '21169304', 'name': 'Vainilla+Vainilla', 'results': 5},
#     {'id': '14839869', 'name': 'Chocolate ice cream', 'results': 5},
#     {'id': '9157604', 'name': 'Verduras', 'results': 4},
#     {'id': '5644063', 'name': 'Delicious strawberry', 'results': 4},
#     {'id': '5035076', 'name': 'Fruit punch', 'results': 4},
#     {'id': '4559461', 'name': 'Milk chocolate', 'results': 4},
#     {'id': '3678607', 'name': 'Frutos rojos', 'results': 4},
#     {'id': '24481730', 'name': 'Cookies', 'results': 4},
#     {'id': '2353054', 'name': 'Uva', 'results': 4},
#     {'id': '2130465', 'name': 'Naranja', 'results': 4},
#     {'id': '18614392', 'name': 'Surtidos', 'results': 4},
#     {'id': '13693206', 'name': 'Frutos', 'results': 4},
#     {'id': '13050143', 'name': 'Dulce de Leche', 'results': 4},
#     {'id': '11313839', 'name': 'Helado de chocolate', 'results': 4},
#     {'id': '9930079', 'name': 'Granada', 'results': 3},
#     {'id': '6955190', 'name': 'Pizza', 'results': 3},
#     {'id': '6104168', 'name': 'Cacao', 'results': 3},
#     {'id': '5646923', 'name': 'Manzana verde', 'results': 3},
#     {'id': '5060352', 'name': 'Watermelon', 'results': 3},
#     {'id': '4820036', 'name': 'Capuccino', 'results': 3},
#     {'id': '3162834', 'name': 'Mix', 'results': 3},
#     {'id': '2301700', 'name': 'Durazno', 'results': 3},
#     {'id': '2301699', 'name': 'Manzana', 'results': 3},
#     {'id': '20245825', 'name': 'VANILLA CUSTARD', 'results': 3},
#     {'id': '19092093', 'name': 'Vanilla bean', 'results': 3},
#     {'id': '17968803', 'name': 'Sin sabor', 'results': 3},
#     {'id': '17240198', 'name': 'Blue raz', 'results': 3},
#     {'id': '13124188', 'name': 'Banana/Frutilla', 'results': 3},
#     {'id': '12227784', 'name': 'Chocolate créme', 'results': 3},
#     {'id': '11703106', 'name': 'Double chocolate chips', 'results': 3},
#     {'id': '11145667', 'name': 'Best whey cookies & cream', 'results': 3},
#     {'id': '11074255',
#      'name': 'Chocolate con mantequilla de maní',
#      'results': 3},
#     {'id': '9777981', 'name': 'Vainilla/Frutilla', 'results': 2},
#     {'id': '7678490', 'name': 'Mousse de chocolate', 'results': 2},
#     {'id': '6723537', 'name': 'Double chocolate', 'results': 2},
#     {'id': '5639167', 'name': 'Frutilla/Banana', 'results': 2},
#     {'id': '5331350', 'name': 'Triple chocolate', 'results': 2},
#     {'id': '5331283', 'name': 'Fudge brownie', 'results': 2},
#     {'id': '5006314', 'name': 'Limonada', 'results': 2},
#     {'id': '26903853', 'name': 'Vainilla', 'results': 2},
#     {'id': '26804207', 'name': 'Frutilla a la crema', 'results': 2},
#     {'id': '24620201', 'name': 'Frutilla-cookies', 'results': 2},
#     {'id': '24449738', 'name': 'Único', 'results': 2},
#     {'id': '18361198', 'name': 'Fruta', 'results': 2},
#     {'id': '15440147', 'name': 'French Vanilla', 'results': 2},
#     {'id': '13124190', 'name': 'Chocolate belga', 'results': 2},
#     {'id': '12082216', 'name': 'Strawberry lime', 'results': 2},
#     {'id': '11642649', 'name': 'Cookies n cream', 'results': 2},
#     {'id': '11579373', 'name': 'Vainilla milkshake', 'results': 2},
#     {'id': '11391596', 'name': 'Banana split', 'results': 2},
#     {'id': '9095811', 'name': 'Tradicional', 'results': 1},
#     {'id': '9095802', 'name': 'Vainilla y frutilla', 'results': 1},
#     {'id': '9095781', 'name': 'Chips de chocolate', 'results': 1},
#     {'id': '9009541', 'name': 'Caffe Latte', 'results': 1},
#     {'id': '9009540', 'name': 'Mokaccino', 'results': 1},
#     {'id': '8897395', 'name': 'Chocolate y Vainilla', 'results': 1},
#     {'id': '6723544', 'name': 'Vanilla cream', 'results': 1},
#     {'id': '5648153', 'name': 'Vainilla/Caramelo', 'results': 1},
#     {'id': '5644077', 'name': 'Frutas', 'results': 1},
#     {'id': '5639233', 'name': 'Maní', 'results': 1},
#     {'id': '5331284', 'name': 'Gourmet vanilla', 'results': 1},
#     {'id': '5282558', 'name': 'Dutch chocolate', 'results': 1},
#     {'id': '5060347', 'name': 'Grape', 'results': 1},
#     {'id': '5060326', 'name': 'Strawberries & cream', 'results': 1},
#     {'id': '4288074', 'name': 'Sandía', 'results': 1},
#     {'id': '3580311', 'name': 'Caramelo', 'results': 1},
#     {'id': '2656159', 'name': 'Mixto', 'results': 1},
#     {'id': '24024290', 'name': 'Rich vanilla', 'results': 1},
#     {'id': '20959793', 'name': 'Açaí', 'results': 1},
#     {'id': '20352279',
#      'name': 'Banana Cream (2 Lbs - 30 Servings)',
#      'results': 1},
#     {'id': '18460714', 'name': 'Strawberry Shortcake', 'results': 1},
#     {'id': '17689494', 'name': 'Doble Chocolate', 'results': 1},
#     {'id': '17240193', 'name': 'Green Lemonade', 'results': 1},
#     {'id': '16834255', 'name': 'Sin sabor', 'results': 1},
#     {'id': '13854288', 'name': 'Almendras', 'results': 1},
#     {'id': '13738648', 'name': '-', 'results': 1},
#     {'id': '13726276', 'name': 'Caramel', 'results': 1},
#     {'id': '13605499', 'name': 'Hierbas', 'results': 1},
#     {'id': '13021728', 'name': 'Vainilla Caramel', 'results': 1},
#     {'id': '12992685', 'name': 'Rich vainilla', 'results': 1},
#     {'id': '12992677', 'name': 'Chocolate bliss', 'results': 1},
#     {'id': '12941111', 'name': 'Grapefruit', 'results': 1},
#     {'id': '12896161', 'name': 'Chocolate y Café', 'results': 1},
#     {'id': '12873522', 'name': 'Mango citric', 'results': 1},
#     {'id': '12240649', 'name': 'Mantequilla de maní', 'results': 1},
#     {'id': '12134995', 'name': 'Gourmet chocolate', 'results': 1},
#     {'id': '11703109', 'name': 'Mocha capuccino', 'results': 1},
#     {'id': '11691853', 'name': 'Grape attack', 'results': 1},
#     {'id': '11691851', 'name': 'Citrus slush', 'results': 1},
#     {'id': '11605529', 'name': 'Naranja/Durazno', 'results': 1},
#     {'id': '11141720', 'name': 'Chocolate banana', 'results': 1},
#     {'id': '11141719', 'name': 'French vainilla', 'results': 1},
#     {'id': '11064126', 'name': 'Chocolate fudge brownie', 'results': 1}]},
#   {'id': 'IS_GLUTEN_FREE',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085',
#      'name': 'Es libre de gluten',
#      'results': 1629}]},
#   {'id': 'IS_VEGAN',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'Es vegano', 'results': 274}]},
#   {'id': 'ITEM_CONDITION',
#    'name': 'Condición',
#    'type': 'STRING',
#    'values': [{'id': '2230284', 'name': 'Nuevo', 'results': 3260},
#     {'id': '2230581', 'name': 'Usado', 'results': 2}]},
#   {'id': 'NET_WEIGHT',
#    'name': 'Peso neto',
#    'type': 'range',
#    'values': [{'id': '(*-908g)', 'name': 'Menos de 908 g', 'results': 984},
#     {'id': '[908g-1.5kg)', 'name': '908 a 1,5 kg', 'results': 1124},
#     {'id': '[1.5kg-3kg)', 'name': '1,5 a 2 kg', 'results': 420},
#     {'id': '[3kg-*)', 'name': '3 kg o más', 'results': 421}]},
#   {'id': 'RECOMMENDED_USE',
#    'name': 'Uso recomendado',
#    'type': 'STRING',
#    'values': [{'id': '5406719', 'name': 'Deportivo', 'results': 1635},
#     {'id': '13117980', 'name': 'Nutricional/Deportivo', 'results': 903},
#     {'id': '10955015', 'name': 'Nutricional', 'results': 209},
#     {'id': '20544220', 'name': 'Fitness', 'results': 3},
#     {'id': '15357238', 'name': 'Comestible', 'results': 1}]},
#   {'id': 'SALE_FORMAT',
#    'name': 'Formato de venta',
#    'type': 'STRING',
#    'values': [{'id': '1359391', 'name': 'Unidad', 'results': 2005},
#     {'id': '1359392', 'name': 'Pack', 'results': 784},
#     {'id': '13763124', 'name': 'Frasco', 'results': 1},
#     {'id': '13392285', 'name': '1', 'results': 1}]},
#   {'id': 'SUPPLEMENT_FORMAT',
#    'name': 'Formato del suplemento',
#    'type': 'STRING',
#    'values': [{'id': '4567842', 'name': 'Polvo', 'results': 2988},
#     {'id': '5642537', 'name': 'Barra', 'results': 56},
#     {'id': '4567841', 'name': 'Cápsulas', 'results': 24},
#     {'id': '13712874', 'name': 'Classic Line', 'results': 14},
#     {'id': '4567839', 'name': 'Comprimidos', 'results': 9},
#     {'id': '4567837', 'name': 'Tabletas', 'results': 9},
#     {'id': '4694469', 'name': 'Líquido', 'results': 7},
#     {'id': '4567838', 'name': 'Barra de cereales', 'results': 6},
#     {'id': '4567844', 'name': 'Gel', 'results': 4},
#     {'id': '4567843', 'name': 'Aceite', 'results': 2},
#     {'id': '14969647', 'name': 'Gotas', 'results': 2},
#     {'id': '11323991', 'name': 'Cápsulas blandas', 'results': 2},
#     {'id': '4567846', 'name': 'Pasta', 'results': 1},
#     {'id': '21099672', 'name': 'Galleta', 'results': 1},
#     {'id': '13739028', 'name': 'Bebible', 'results': 1},
#     {'id': '13672833', 'name': 'Gramos', 'results': 1},
#     {'id': '13645634', 'name': 'en polvo', 'results': 1}]},
#   {'id': 'UNITS_PER_PACKAGE',
#    'name': 'Unidades por envase',
#    'type': 'range',
#    'values': [{'id': '[1-1]', 'name': 'Por unidad', 'results': 1846},
#     {'id': '[2-10)', 'name': '2 a 9 unidades', 'results': 270},
#     {'id': '[10-30)', 'name': '10 a 29 unidades', 'results': 104},
#     {'id': '[30-*)', 'name': '30 unidades o más', 'results': 79}]},
#   {'id': 'UNIT_VOLUME',
#    'name': 'Volumen de la unidad',
#    'type': 'range',
#    'values': [{'id': '(*-500mL)', 'name': 'Menos de 500 mL', 'results': 358},
#     {'id': 'L-1L)', 'name': '500 a 1 L', 'results': 497},
#     {'id': '[1L-1.5L)', 'name': '1 a 1,5 L', 'results': 344},
#     {'id': '[1.5L-*)', 'name': '1,5 L o más', 'results': 342}]},
#   {'id': 'official_store',
#    'name': 'Tiendas oficiales',
#    'type': 'text',
#    'values': [{'id': 'all',
#      'name': 'Todas las tiendas oficiales',
#      'results': 515},
#     {'id': '65728', 'name': 'Ecomodico', 'results': 233},
#     {'id': '1299', 'name': 'ENA', 'results': 14}]},
#   {'id': 'product',
#    'name': 'Producto',
#    'type': 'text',
#    'values': [{'id': 'MLA12457845',
#      'name': 'Suplemento en polvo Nutrilab  Whey Pro proteína',
#      'results': 59},
#     {'id': 'MLA23038663',
#      'name': 'Star Nutrition Whey Protein 2 Lb Sabor Banana Cream Doypack',
#      'results': 5},
#     {'id': 'MLA14287435',
#      'name': 'Suplemento en polvo ENA Sport  True Made Whey Protein proteínas sabor vanilla ice cream en pote de 930g',
#      'results': 3},
#     {'id': 'MLA14287436',
#      'name': 'Suplemento en polvo ENA Sport  True Made Whey Protein proteínas sabor cookies & cream en pote de 930g',
#      'results': 3},
#     {'id': 'MLA18510994',
#      'name': 'Suplemento en polvo ENA Sport  True Made proteínas sabor vanilla ice cream en Doypack 453g',
#      'results': 3},
#     {'id': 'MLA18710125',
#      'name': 'Suplemento en polvo Star Nutrition.  Platinum Platinum Whey Protein proteína sabor cookies & cream en pote de 907g',
#      'results': 3},
#     {'id': 'MLA19544897',
#      'name': 'Star Nutrition Whey Protein 2 Lb Sabor Chocolate suizo DOYPACK',
#      'results': 3},
#     {'id': 'MLA23059605',
#      'name': 'Ena 100% Whey Protein. Proteina Concentrada ',
#      'results': 3}]}],
#  'pdp_tracking': {'group': False,
#   'product_info': [{'id': 'MLA14287435', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA14287437', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA18710124', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA18529580', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA14287436', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA18529578', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA18725805', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA18907239', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA18529577', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA25948162', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA19544897', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA18529579', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA19532603', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA18510993', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA19051754', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA19545071', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA19642879', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA14287438', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA18486932', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA18592256', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA18942070', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA14287448', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA19893561', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA14287452', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA18710122', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA18569171', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA18710125', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA18593779', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA19051752', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA19532649', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA14287449', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA14481585', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA23038665', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA18623215', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA18942071', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA22777038', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA18486933', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA19564634', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA18614935', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA23038664', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA18614932', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA28608959', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA18486930', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA18510994', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA19051751', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA18623209', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA19532612', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA18942069', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA22857294', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA26054307', 'score': 1, 'status': 'shown'}]}}

# %% [markdown]
#  De aquí obtenemos el total de resultados que es de unos 6248 items en su totalidad

# %% [markdown]
# #### Ejercicio 2
# Guarden los precios de los ítems obtenidos en un dataframe y calculen el precio promedio, el mínimo y el máximo.

# %%
import pandas as pd 
## Aquí lo que hacemos es llamar a pandas pd
## Ahora sacaremos los datos de los precios:
precios = data['results']
## Creamos al dataframe a traves de Pandas
df = pd.DataFrame(precios)
## Ahora sacamos el precio mínimo, máximo y por último el promedio.
precio_minimo = df['price'].min()
precio_maximo = df['price'].max()
precio_promedio = df['price'].mean()

print("Precio mínimo:", precio_minimo)
print("Precio máximo:", precio_maximo)
print("Precio promedio:", precio_promedio)
# Out:
# Precio mínimo: 7100.0
# Precio máximo: 78719.0
# Precio promedio: 27067.998199999998

# %% [markdown]
# #### Ejercicio 3
# Armen un histograma de los precios. ¿Ven algún <i>outlier<i>?
# Nota: pueden usar la librería de Matplotlib o la de Pandas.

# %%
import matplotlib.pyplot as plt

# %%
## Para crear un histograma, hacemos el siguiente método:
# Creamos el histogra,a
plt.hist(df['price'], bins=7, color='blue', edgecolor='black')

# Le agregamos detalles al gráfico
plt.xlabel('Precio')
plt.ylabel('Frecuencia')
plt.title('Histograma de Precios de Items de Proteína')

# Mostramos el histograma:
plt.show()

# %% [markdown]
# En principio, los outlayers en principio lo que hacen es subir el promedio. El precio de las proteinas en general son de un 27 mil pesos, por ende, todo precio superior a los 50 y inferior a los 11 podrían ser considerados outlayers

# %% [markdown]
# #### Ejercicio 4
# Realicen alguna consulta adicional utilizando la API de Mercado Libre (debe ser alguna consulta que no se haya visto en clase. Por ejemplo, obtener los ítems de un vendedor en particular, obtener los productos de una categoría u otros). Analicen los resultados y comenten uno o dos que les parezcan interesantes (por ejemplo, precios promedio de los productos de un vendedor, diferencia entre el precio original y actual, si acepta mercado pago para la compra de productos, etc.)

# %%
import requests

def obtener_productos_por_vendedor_en_categoria(id_vendedor, categoria):
    url = f"https://api.mercadolibre.com/sites/MLA/search?seller_id=355576322&category=MLA409431"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        return data['results']
    else:
        print("Error al realizar la solicitud:", response.status_code)
        return []

def obtener_precio_promedio_por_categoria(productos):
    precio_promedio_por_categoria = {}
    for producto in productos:
        categoria = producto['category_id']
        precio = producto['price']
        if categoria in precio_promedio_por_categoria:
            precio_promedio_por_categoria[categoria]['total'] += precio
            precio_promedio_por_categoria[categoria]['count'] += 1
        else:
            precio_promedio_por_categoria[categoria] = {'total': precio, 'count': 1}
    for categoria, data in precio_promedio_por_categoria.items():
        precio_promedio_por_categoria[categoria]['promedio'] = data['total'] / data['count']
    return precio_promedio_por_categoria

# ID del vendedor y categoría de interés
id_vendedor = "355576322"
categoria = "MLA409431"

# Conseguimos los productos del vendedor en la categoría que queremos
productos = obtener_productos_por_vendedor_en_categoria(355576322, categoria)

# Calculamos el precio promedio por categoría
precio_promedio_por_categoria = obtener_precio_promedio_por_categoria(productos)

# Imprimir el precio promedio por categoría
for categoria, data in precio_promedio_por_categoria.items():
    print(f"Categoría: {categoria}, Precio Promedio: {data['promedio']}")
# Out:
# Categoría: MLA8830, Precio Promedio: 20187.55487804878
# Categoría: MLA455048, Precio Promedio: 4783.5
# Categoría: MLA95334, Precio Promedio: 14581.865
# Categoría: MLA3551, Precio Promedio: 19094.0
# Categoría: MLA412710, Precio Promedio: 6266.0
# Categoría: MLA455050, Precio Promedio: 1939.99

# %% [markdown]
# Aquí obtenemos todos los precios promdios de distintas categorías dentro de los productos, y podemos obtener el precio promedio de cada categoría

# %% [markdown]
# ### Parte B

# %% [markdown]
# #### Ejercicio 5
# De la página de noticias del [diario La Nación](https://www.lanacion.com.ar/), utilicen herramientas de web scraping para obtener los links de las noticias de la portada. Guarden los links obtenidos en un dataframe y expórtenlo a un archivo de excel.
#
# Nota 1: es posible que logren obtener los links a las noticias sin el dominio: "https://www.lanacion.com.ar/". De ser así, concatenen el dominio a la ruta del link obtenido, tal que se obtenga un link al que se pueda acceder. Es decir, que las cadenas de caracteres finales tendrán la forma: https://www.lanacion.com.ar/*texto_obtenido*)
#
# Nota 2: junto con su entrega, adjunten una captura de la página de noticias al momento de correr su código. Eso servirá al momento de la corrección para verificar que los links obtenidos hacen referencia a las noticias de ese día y hora.

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

url = 'https://www.lanacion.com.ar/'

response = requests.get(url)

soup = BeautifulSoup(response.content, 'html.parser')

titulos = soup.find_all('h2', class_="text ln-text title --prumo --font-medium --font-m-l")

titulos_extraidos = [titulo.text.strip() for titulo in titulos]

df = pd.DataFrame({'Títulos': titulos_extraidos})

print("Los títulos se cargaron correctamente:")
print(df.head())

nombre_archivo = 'titulos_noticias_corregido.xlsx'
df.to_excel(nombre_archivo, index=False)
# Out:
# Los títulos se cargaron correctamente:
#                                              Títulos
# 0  Los candidatos de Milei. La casta ya no tiene ...
# 1  El futuro de la Corte Suprema. El Gobierno con...
# 2  Presionado por la oposición. El Gobierno cambi...
# 3  “Es brava”. Villarruel habló de su relación co...
# 4  "¿Alguien cree que el Presidente va a irse?" E...
